# %% [markdown]
# # Type Casting

# %% [markdown]
# Converting one data type to another

# %% [markdown]
# ### int
# ### float
# ### complex
# ### string
# ### boolean

# %% [markdown]
# # Int
# - int-float
# - int-str
# - int-complex
# - int-bool

# %%
a=100

# %%
type(a)
# Out:
# int

# %%
float(a)
# Out:
# 100.0

# %%
complex(a)
# Out:
# (100+0j)

# %%
str(a)
# Out:
# '100'

# %%
bool(a)
# Out:
# True

# %% [markdown]
# ### float
# - float-int
# - float-complex
# - float-str
# - float-bool

# %%
b=12.50
type(b)
# Out:
# float

# %%
int(b)
# Out:
# 12

# %%
complex(b)
# Out:
# (12.5+0j)

# %%
str(b)
# Out:
# '12.5'

# %% [markdown]
# ### string
# - np str-int
# - np str-float
# - np str-complex
# - str-bool

# %%
name='nithin'

# %%
type(name)
# Out:
# str

# %%
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 int(name)
#
# ValueError: invalid literal for int() with base 10: 'nithin'

# %%
complex(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 complex(name)
#
# ValueError: complex() arg is a malformed string

# %%
bool(name)
# Out:
# True

# %% [markdown]
# ### Complex
#
# - np complex-int
# - np complex-float
# - complex-str
# - complex-bool

# %%
comp=10+2j

# %%
type(comp)
# Out:
# complex

# %%
int(comp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 int(comp)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
float(comp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 float(comp)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
str(comp)
# Out:
# '(10+2j)'

# %%
bool(comp)
# Out:
# True
