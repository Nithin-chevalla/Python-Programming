# %% [markdown]
# - In string literals we can use escape characters to assosiate a special meaning

# %%
da="Data\nAnalytics" # \n is used for printing in new line

# %%
da # called Directly so came wrong
# Out:
# 'Data\nAnalytics'

# %%
print(da)
# Out:
# Data
# Analytics

# %%
# \t for one tab distance
gd= "Graphic\tDesign"

# %%
print(gd)
# Out:
# Graphic	Design

# %%
# \t\t for more tab space
Gd= "Graphic\t\tDesign"

# %%
print(Gd)
# Out:
# Graphic		Design

# %%
# \b for backspace
jd="mani\bpopulation"

# %%
print(jd)
# Out:
# manpopulation

# %%
# \v for vertical tab
jv="mani\vpopulation"

# %%
print(jv)
# Out:
# manipopulation

# %% [markdown]
# - task
# - 1.\r
# - 2.\f
# - 3. \'
# - 4. \\

# %%
n="mani\rpop"

# %%
print(n)
# Out:
# popi

# %%
m="mani\fpop"

# %%
print(m)
# Out:
# manipop

# %%
o="mani\'pop"

# %%
print(o)
# Out:
# mani'pop

# %%
p="mani\\pop"

# %%
print(p)
# Out:
# mani\pop
