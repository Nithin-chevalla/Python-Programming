# %% [markdown]
# # Tuple Data Structure

# %% [markdown]
# - Tuple is exactly same as the list except that it is immutable, once we create we cannot modify.

# %% [markdown]
# 1. Insertion order is preserve
# 2. Duplicates are allowed
# 3. Hetrogeneous object are allowed
# 4. we use () to store elements,separated by ,

# %%
t=(1,2,4,5)

# %%
t
# Out:
# (1, 2, 4, 5)

# %%
type(t)
# Out:
# tuple

# %%
t=()

# %%
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t=(10) # if we write only element it takes as int

# %%
t
# Out:
# 10

# %%
type(t)
# Out:
# int

# %%
t=(10,) # if we write like this it will take as tuple

# %%
t
# Out:
# (10,)

# %%
type(t)
# Out:
# tuple

# %%
# different ways 
t=()
t=12,3,4,5,6
t=12
t=4,
t=(10,)
t=(10,20,30)

# %%
list1=['sunny','bunny','funnny']

# %%
type(list1)
# Out:
# list

# %%
t=tuple(list1)

# %%
t
# Out:
# ('sunny', 'bunny', 'funnny')

# %%
type(t)
# Out:
# tuple

# %%
t=tuple(range(0,10,2))

# %%
t
# Out:
# (0, 2, 4, 6, 8)

# %%
# How to access elements of tuple
# either by indexing/slicing

# %% [markdown]
# # By using Index

# %%
t=10,20,30,40

# %%
t[0]
# Out:
# 10

# %%
t[3]
# Out:
# 40

# %%
t[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 t[5]
#
# IndexError: tuple index out of range

# %% [markdown]
# # by using slicing Operator

# %%
t=10,20,30,40,50,60,70,80,90
# 0, 1, 2, 3, 4, 5, 6, 7, 8          ===>indexes

# %%
t[2:5]
# Out:
# (30, 40, 50)

# %%
t[3:8:2]
# Out:
# (40, 60, 80)

# %% [markdown]
# # Mathematical Operator on tuple

# %%
t1=10,20,30
t2=40,50,60

# %%
#concatenation
t3=t1+t2
t3
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
t4=t1*3
t4
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %% [markdown]
# # Few functions in tuple

# %% [markdown]
# # len()

# %%
tu=(10,20,30,40,50,60,70,80,90,10,20,30,40,10,10,10)

# %%
len(tu)
# Out:
# 16

# %% [markdown]
# # Count()

# %%
tu.count(10)
# Out:
# 5

# %% [markdown]
# # index()

# %%
tu.index(90)
# Out:
# 8

# %% [markdown]
# # sorted()

# %%
t1=90,40,28,49,10,3,0,20,14

# %%
t1_sorted=sorted(t1) # ===> sorted() will read the given & make copy of it but original will remain same, but sort() directly changes the original itself

# %%
t1_sorted
# Out:
# [0, 3, 10, 14, 20, 28, 40, 49, 90]

# %%
t1
# Out:
# (90, 40, 28, 49, 10, 3, 0, 20, 14)

# %%
tup='a','z','d','l','e','b','c'

# %%
tup_sorted=sorted(tup)

# %%
tup_sorted
# Out:
# ['a', 'b', 'c', 'd', 'e', 'l', 'z']

# %%
min(tup)
# Out:
# 'a'

# %%
max(tup)
# Out:
# 'z'

# %%
t1=10,20,30
t2=40,50,60

# %%
t3=10,20,30

# %%
t1==t3
# Out:
# True

# %%
t2==t3
# Out:
# False

# %%
# Tuple Packing and unpacking

# %%
a=10
b=20
c=30
d=40

# %%
t=a,b,c,d

# %%
t
# Out:
# (10, 20, 30, 40)

# %%
type(t)
# Out:
# tuple

# %%
# unpacking

# %%
tu=(2,3,4,5,6,7,8)

# %%
a,b,c,d,e,f,g=tu

# %%
a,b,c,d,e,f,g
# Out:
# (2, 3, 4, 5, 6, 7, 8)

# %% [markdown]
# # difference List vs Tuple

# %% [markdown]
# 1. Mutable / Immutable
# 2. []/()
# 3. sort()&sorted() / only sorted()
# 4. Growble / read only mode(list)
