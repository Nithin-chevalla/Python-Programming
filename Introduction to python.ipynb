# %% [markdown]
# 1. for running the python we need software known compiler or interpreter
# 2. for writting we use pycharm software

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# code==>ide==>Interpreter/compiler==>Byte_code==>pvm==>output==>ide

# %% [markdown]
# Python is a General purpose programming language
# eg: solving the problem, Automating the things, Operarting the operating system
# Python is a high level programming language
# Developed by Guido Van Rossam in 1989, Working in National Research Institute at Netherland.
# But officially Python was launched in FEB 20 1991.
# This is the first programming language for beginners.

# %%
a=20
b=30
a+b
# Out:
# 50

# %% [markdown]
# Python is open source = anyone can download
# c + python = cpython

# %% [markdown]
# ***How guido has written the Python***

# %%
# 1. Functional programming features from C.
# 2. Object Oriented Programming from C++.
# 3. Scripting language feature from perl and shell
# # 4. Modular proramming from Modula-3.
# 5. Most of the syntax from C and ABC.

# %% [markdown]
# **Features of Python**

# %%
# 1. Python is simple and easy
# 2. freeware and open source
# 3. High level Programming language
# 4. platform Independent
# 5. Portable language
# 6. Dynamically typed language
# 7. Procedure Oriented (eg:c) and Object oriented (eg: C++/ java)
# 8. Interpreted language.
# 9. Extensible language ( with python you can other programming languages )
# 10. Embedded
# 11. Extensive library

# %% [markdown]
# #### Flavours of Python ####

# %% [markdown]
# C + Python = Cpython
# C + python = cython
# java + Python = Jython
# Python + python = Pypython
# Anaconda + python = Anacondapython

# %% [markdown]
# #### Versions In Python ####

# %%
# Python 1.0 V- Jan 1994
# Python 2.0 V- oct 2000
# Python 3.0 V- Dec 2008
