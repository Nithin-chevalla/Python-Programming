# %% [markdown]
# # Dict data structure

# %% [markdown]
# key:"value"

# %% [markdown]
# 1. key - unique
# 2. values can be duplicate

# %% [markdown]
# - If we need to represent the data in one as object other as feature of object

# %% [markdown]
# 1. Insertion order does not preserve
# 2. duplicates are allowed
# 3. it is mutable
# 4. dynamic
# 5. Indexing and slicing is not applicable

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d=dict()

# %%
type(d)
# Out:
# dict

# %%
d[100]="Anil"
d[200]="Nithin"
d[300]="virat"

# %%
d
# Out:
# {100: 'Anil', 200: 'Nithin', 300: 'virat'}

# %%
d={"key":"value"}

# %% [markdown]
# # how to access data from dictionary

# %%
d={100:"abhi",200:"ishan",300:"tilak"}

# %%
d[100]
# Out:
# 'abhi'

# %%
d[300]
# Out:
# 'tilak'

# %%
d[400]="surya"

# %%
d
# Out:
# {100: 'abhi', 200: 'ishan', 300: 'tilak', 400: 'surya'}

# %%
d[300]="sanju" # replacing the value

# %%
d
# Out:
# {100: 'abhi', 200: 'ishan', 300: 'sanju', 400: 'surya'}

# %% [markdown]
# # delete element from dict

# %%
d={100:"abhi",200:"ishan",300:"tilak"}

# %%
del d[200]

# %%
d
# Out:
# {100: 'abhi', 300: 'tilak'}

# %%
d.clear() # to clear everything

# %%
d
# Out:
# {}

# %%
del d #deleting the variable also

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 d
#
# NameError: name 'd' is not defined

# %% [markdown]
# # Important functions of Dictionary

# %%
d=dict()

# %%
d=dict({100:"apple",200:"mango"})

# %%
d
# Out:
# {100: 'apple', 200: 'mango'}

# %%
len(d)
# Out:
# 2

# %%
d.get(100)
# Out:
# 'apple'

# %%
d.get(200)
# Out:
# 'mango'

# %%
d.pop(100) # used to delete the element
# Out:
# 'apple'

# %%
d
# Out:
# {200: 'mango'}

# %%
d={'blue':'skygreen','sky':'skyblue'}

# %%
# it is used to delete arbitary item( key-value)
d.popitem()
# Out:
# ('sky', 'skyblue')

# %% [markdown]
# # return associated keys with each dictionary

# %%
d={1:"10th",2:"12th",3:"degree"}

# %%
d.keys() # used to return dict keys
# Out:
# dict_keys([1, 2, 3])

# %%
for i in d.keys():
    print(i)
# Out:
# 1
# 2
# 3

# %%
d.values() # sed to print values
# Out:
# dict_values(['10th', '12th', 'degree'])

# %%
for i in d.values():
    print(i)
# Out:
# 10th
# 12th
# degree

# %%
d1=d.copy() # used to copy dict

# %%
d1
# Out:
# {1: '10th', 2: '12th', 3: 'degree'}

# %%
# write a program to take  dictionary as input and get the sum of its values

# %%
d1=eval(input("Enter dictionary: "))
print(sum(d1.values()))
# Out:
# Enter dictionary:  {'a':10,'b':20}
# 30
