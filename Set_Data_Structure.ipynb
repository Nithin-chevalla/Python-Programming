# %% [markdown]
# # set Data structure

# %% [markdown]
# - If we want to represent a group of elements then we should use set

# %% [markdown]
# 1. Duplicates are not allowed
# 2. Insertion order is not preserve
# 3. We can sort the elements
# 4. Hetrogeneous objects are allowed
# 5. we cannot use indexing and slicing

# %%
s={10,23,4,5,6}

# %%
type(s)
# Out:
# set

# %%
list1=[10,20,30,40,10,30,40,50,12,30,40]
list1
# Out:
# [10, 20, 30, 40, 10, 30, 40, 50, 12, 30, 40]

# %%
s=set(list1)

# %%
s
# Out:
# {10, 12, 20, 30, 40, 50}

# %%
five=set(range(5))

# %%
five
# Out:
# {0, 1, 2, 3, 4}

# %%
s={}

# %%
s
# Out:
# {}

# %%
type(s)
# Out:
# dict

# %%
s=set(s)
s
type(s)
# Out:
# set

# %% [markdown]
# # Few function of set

# %%
s={10,20,30}

# %%
s.add(40) # adding one element

# %%
s
# Out:
# {10, 20, 30, 40}

# %% [markdown]
# # adding multiple elements

# %%
l=[50,60,70,80]

# %%
s.update(l)

# %%
s
# Out:
# {10, 20, 30, 40, 50, 60, 70, 80}

# %% [markdown]
# # copy()

# %%
s={10,30,40,50}

# %%
s1=s.copy()

# %%
s1
# Out:
# {10, 30, 40, 50}

# %%
s1.pop() # ===> it randomly removes any value
# Out:
# 40

# %%
s1
# Out:
# {10, 30, 50}

# %%
s1.pop()
# Out:
# 10

# %%
s1
# Out:
# {30, 50}

# %%
s1.remove(50) # ===> it removes whatever we specify

# %%
s1
# Out:
# {30}

# %%
s1.remove(100) # if the set does not contain specified element then it will show error to avoid error we use discard()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 s1.remove(100)
#
# KeyError: 100

# %%
s1.discard(100)

# %%
s1
# Out:
# {30}

# %%
set1={1,2,3,4,5,6,7,8}

# %%
set1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
set1.clear()

# %%
set1
# Out:
# set()

# %% [markdown]
# # Mathematical operators

# %% [markdown]
# # 1. union()

# %%
s1={10,20,30}
s2={30,40,50,60,70}

# %%
s1.union(s2)
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
s1|s2
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %% [markdown]
# # 2. Intersection

# %%
s1.intersection(s2)
# Out:
# {30}

# %%
s1&s2
# Out:
# {30}

# %%
# write a program to print different vowels in the given word

# %%
s="Learning python is easy"

# %%
s1=set(s)

# %%
v1={'a','e','i','o','u'}

# %%
s1.intersection(v1)
# Out:
# {'a', 'e', 'i', 'o'}

# %%
v2={'a','e','i','o','u'}
s2=set(input("enter the string"))
s2.intersection(v2)
# Out:
# enter the string i am nithin from hyderabad
# {'a', 'e', 'i', 'o'}

# %%
# write a prgram to remove duplicates from a list

# %%
lis=list(input("enter a list"))
s=set(lis)
s
# Out:
# enter a list 1111111122222223333333333344444
# {'1', '2', '3', '4'}

# %%
#example of above but in lists
list1=list(input("enter a list").split())
list2=list(input("enter the second list").split())
set1=set(list1)
set2=set(list2)
set1.union(set2)
# Out:
# enter a list 10 20 30 40
# enter the second list 30 40 50 60
# {'10', '20', '30', '40', '50', '60'}
